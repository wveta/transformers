# %%
# %pip install ruprompts
# Out:
# Collecting ruprompts
#   Downloading ruprompts-0.1.4-py3-none-any.whl (29 kB)
# Collecting torch<2.0.0,>=1.10.0 (from ruprompts)
#   Downloading torch-1.13.1-cp310-cp310-manylinux1_x86_64.whl (887.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.5/887.5 MB 1.1 MB/s eta 0:00:00
# Collecting torchtyping<0.2.0,>=0.1.4 (from ruprompts)
#   Downloading torchtyping-0.1.4-py3-none-any.whl (17 kB)
# Collecting transformers<5.0.0,>=4.6.0 (from ruprompts)
#   Downloading transformers-4.35.2-py3-none-any.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 109.9 MB/s eta 0:00:00
# Collecting typeguard<3.0.0,>=2.13.3 (from ruprompts)
#   Downloading typeguard-2.13.3-py3-none-any.whl (17 kB)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.0.1 in /usr/local/lib/python3.10/dist-packages (from ruprompts) (4.5.0)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch<2.0.0,>=1.10.0->ruprompts)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 64.8 MB/s eta 0:00:00
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch<2.0.0,>=1.10.0->ruprompts)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.7 MB/s eta 0:00:00
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch<2.0.0,>=1.10.0->ruprompts)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 2.7 MB/s eta 0:00:00
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch<2.0.0,>=1.10.0->ruprompts)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 79.5 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0,>=1.10.0->ruprompts) (67.7.2)
# Requirement already satisfied: wheel in /usr/local/lib/python3.10/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch<2.0.0,>=1.10.0->ruprompts) (0.41.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->ruprompts) (3.13.1)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers<5.0.0,>=4.6.0->ruprompts)
#   Downloading huggingface_hub-0.19.4-py3-none-any.whl (311 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.7/311.7 kB 36.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->ruprompts) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->ruprompts) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->ruprompts) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->ruprompts) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->ruprompts) (2.31.0)
# Collecting tokenizers<0.19,>=0.14 (from transformers<5.0.0,>=4.6.0->ruprompts)
#   Downloading tokenizers-0.15.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 106.7 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers<5.0.0,>=4.6.0->ruprompts)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.7 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.6.0->ruprompts) (4.66.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers<5.0.0,>=4.6.0->ruprompts) (2023.6.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.6.0->ruprompts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.6.0->ruprompts) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.6.0->ruprompts) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers<5.0.0,>=4.6.0->ruprompts) (2023.7.22)
# Installing collected packages: typeguard, safetensors, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cublas-cu11, nvidia-cudnn-cu11, huggingface-hub, torch, tokenizers, transformers, torchtyping, ruprompts
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu118
#     Uninstalling torch-2.1.0+cu118:
#       Successfully uninstalled torch-2.1.0+cu118
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu118 requires torch==2.1.0, but you have torch 1.13.1 which is incompatible.
# torchdata 0.7.0 requires torch==2.1.0, but you have torch 1.13.1 which is incompatible.
# torchtext 0.16.0 requires torch==2.1.0, but you have torch 1.13.1 which is incompatible.
# torchvision 0.16.0+cu118 requires torch==2.1.0, but you have torch 1.13.1 which is incompatible.
# Successfully installed huggingface-hub-0.19.4 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 ruprompts-0.1.4 safetensors-0.4.0 tokenizers-0.15.0 torch-1.13.1 torchtyping-0.1.4 transformers-4.35.2 typeguard-2.13.3

# %% [markdown]
# In this tutorial we show how to load and use the pretrained prompts from HuggingFace Hub.

# %%
# although not used directly, this import is necessary,
# since it adds our custom pipelines to transformers
import ruprompts

from transformers import pipeline

# %% [markdown]
# Let's first load the joke prompt:

# %%
ppln_joke = pipeline("text-generation-with-prompt", prompt="konodyuk/prompt_rugpt3large_joke", device=0)
# Out:
# No model was supplied, defaulted to sberbank-ai/rugpt3large_based_on_gpt2 and revision aa2b602 (https://huggingface.co/sberbank-ai/rugpt3large_based_on_gpt2).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# (…)e_based_on_gpt2/resolve/main/config.json:   0%|          | 0.00/609 [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/transformers/models/auto/modeling_auto.py:1509: FutureWarning: The class `AutoModelWithLMHead` is deprecated and will be removed in a future version. Please use `AutoModelForCausalLM` for causal language models, `AutoModelForMaskedLM` for masked language models and `AutoModelForSeq2SeqLM` for encoder-decoder models.
#   warnings.warn(
# pytorch_model.bin:   0%|          | 0.00/3.14G [00:00<?, ?B/s]
# (…)ge_based_on_gpt2/resolve/main/vocab.json:   0%|          | 0.00/1.71M [00:00<?, ?B/s]
# (…)ge_based_on_gpt2/resolve/main/merges.txt:   0%|          | 0.00/1.27M [00:00<?, ?B/s]
# (…)ugpt3large_joke/resolve/main/prompt.json:   0%|          | 0.00/499 [00:00<?, ?B/s]
# prompt_provider.bin:   0%|          | 0.00/369k [00:00<?, ?B/s]

# %% [markdown]
# Note that we didn't specify the `model=` and `tokenizer=` arguments. They are inferred from pretrained prompt config.
#
# Using the pipeline with prompt is almost identical to using the regular text generation pipeline:

# %%
ppln_joke("Говорит как-то дуб вороне")
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': 'Говорит как-то дуб вороне - вороне: "Спать ложись!"И ворона легла...<pad>'}]

# %% [markdown]
# Although it is more convenient to omit model arguments, it leads to reinstantiation of the same model each time we create a pipeline. An easy fix is to create model and tokenizer once and then pass it to all the pipelines:

# %%
from transformers import GPT2LMHeadModel, AutoTokenizer

model_id = "sberbank-ai/rugpt3large_based_on_gpt2"
model = GPT2LMHeadModel.from_pretrained(model_id)
tokenizer = AutoTokenizer.from_pretrained(model_id)

# %% [markdown]
# It will speed up loading the proverb pipeline:

# %%
ppln_proverb = pipeline("text-generation-with-prompt", prompt="konodyuk/prompt_rugpt3large_proverb", model=model, tokenizer=tokenizer, device=0)
ppln_proverb("Сколько ни")
# Out:
# (…)t3large_proverb/resolve/main/prompt.json:   0%|          | 0.00/499 [00:00<?, ?B/s]
# prompt_provider.bin:   0%|          | 0.00/369k [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': 'Сколько ни говори, а делу ни конца, ни края.<pad>'}]

# %% [markdown]
# Loading and using text2text prompts is almost identical:

# %%
ppln_detox = pipeline("text2text-generation-with-prompt", prompt="konodyuk/prompt_rugpt3large_detox_russe", model=model, tokenizer=tokenizer, device=0)
ppln_detox({"toxic_comment": "Ублюдок, мать твою, а ну иди сюда"})
# Out:
# (…)rge_detox_russe/resolve/main/prompt.json:   0%|          | 0.00/837 [00:00<?, ?B/s]
# prompt_provider.bin:   0%|          | 0.00/738k [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': 'А ну иди сюда<pad>'}]

# %%
long_text = """Несмотря на споры, большинство учёных сошлись во мнении, что кошка является полуодомашненным животным, то есть она способна на сосуществование с человеком, но, потеряв с ним контакт, легко возвращаются к дикому образу существования. Хотя у кошки наблюдаются генетические изменения в сравнении с диким предком, эта разница в 10 раз меньше, чем у собак с волками. Учёные считают, что дикая кошка действительно могла сама прийти к человеку, чтобы питаться грызунами, а такие отношения характеризовались как соседские, и уже через несколько тысяч лет люди сами стали одомашнивать маленьких хищников. Это также, вероятно, объясняет, почему модель поведения кошки почти не изменилась; при одомашнивании собаки из волка человек изменил её образ жизни и среду обитания, кошка же претерпела минимальные изменения Кошка сумела сохранить модель поведения, присущую её диким предкам. Она почти так же хорошо охотится, как дикая кошка, но в то же время способна мирно сосуществовать с человеком, проявлять к нему эмоциональную привязанность, нежность или даже выказывать игривое поведение."""
ppln_summary = pipeline("text2text-generation-with-prompt", prompt="konodyuk/prompt_rugpt3large_summarization_mlsum", model=model, tokenizer=tokenizer, device=0)

ppln_summary(long_text, num_beams=2, num_return_sequences=2)
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': 'Учёные пришли к выводу, что кошка могла прийти к человеку, чтобы питаться грызунами<pad><pad><pad><pad><pad><pad><pad><pad><pad><pad><pad>'},
#  {'generated_text': 'Учёные пришли к выводу, что кошка могла прийти к человеку, чтобы питаться грызунами, а такие отношения характеризовались как соседские<pad>'}]

# %%
ppln_summary = pipeline("text2text-generation-with-prompt", prompt="konodyuk/prompt_rugpt3large_title_mlsum", model=model, tokenizer=tokenizer, device=0)
ppln_summary(long_text, num_beams=2, num_return_sequences=2)
# Out:
# (…)rge_title_mlsum/resolve/main/prompt.json:   0%|          | 0.00/371 [00:00<?, ?B/s]
# prompt_provider.bin:   0%|          | 0.00/185k [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': 'Кошка-человек<pad><pad><pad><pad>'},
#  {'generated_text': 'Кошка-полуночник<pad>'}]

# %% [markdown]
# In some cases pipeline takes multiple arguments:

# %%
context = """В 1997 году Шмидхубер и Сепп Хохрайтер опубликовали работу, описывающую рекуррентную нейронную сеть, которую авторы назвали «Долгая краткосрочная память». В 2015 году эта архитектура была использована в новой реализации распознавания речи в программном обеспечении компании Google для смартфонов.

Исследования Шмидхубера также включают в себя генерализации колмогоровской сложности и метрики «скорость важна» (Speed Prior), создание концепции Машины Гёделя.

В 2014 году Шмидхубер основал компанию Nnaisense для работы в сфере коммерческого применения технологий искусственного интеллекта в таких областях как финансы, тяжёлая промышленность и самоуправляемый автотранспорт. Сепп Хохрайтер и Яан Таллинн занимают в компании пост советников."""

ppln_qa = pipeline("text2text-generation-with-prompt", prompt="konodyuk/prompt_rugpt3large_qa_sberquad", model=model, tokenizer=tokenizer, device=0)
ppln_qa({"context": context, "question": "С кем Шмидхубер опубликовал работу?"})
# Out:
# (…)rge_qa_sberquad/resolve/main/prompt.json:   0%|          | 0.00/549 [00:00<?, ?B/s]
# prompt_provider.bin:   0%|          | 0.00/369k [00:00<?, ?B/s]
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': 'с коллективом сотрудников<pad>'}]

# %% [markdown]
# So far we needed to create a separate pipeline for each task. It may be inconvenient if you want to serve multiple prompts simultaneously. For this case we provide a more low-level interface, called MultiPrompt:

# %%
from ruprompts import MultiPrompt

mp = MultiPrompt({
    "detox": "konodyuk/prompt_rugpt3large_detox_russe",
    "qa": "konodyuk/prompt_rugpt3large_qa_sberquad",
})
mp.patch(model, tokenizer)

# %% [markdown]
# Now we need to create a regular generation pipeline:

# %%
ppln = pipeline("text-generation", model=model, tokenizer=tokenizer, device=0, return_full_text=False, do_sample=True, eos_token_id=0, max_new_tokens=100)

# %% [markdown]
# To switch the task, we just need to change the key:

# %%
ppln(mp(key="detox", toxic_comment="Какого черта ты сюда припёрся?"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': 'Почему ты сюда пришел<pad>'}]

# %%
ppln(mp(key="qa", context=context, question="В каком году была основана Nnaisense?"))
# Out:
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# [{'generated_text': 'В 2014<pad>'}]
